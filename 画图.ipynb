# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.style.use({'figure.figsize':(20, 12)})
f=open('C++np/cmake-build-debug/new_data.txt')
val=[]
for line in f.readlines():
    line=line.strip('\n').split(' ')
    a=[]
    for i in line:
        a.append(int(i))
    val.append(a)
index=[]
for i in range(60):
    index.append(i)
mx=-1
for i in range(60):
    mx=max(mx,val[14][i])
print(mx)
for i in range(24):
    val_h=val[i]
    p=sns.barplot(x=index,y=val_h)
    plt.savefig('20190916杭州萧山国际机场排队打车等待总时间/20190916杭州萧山国际机场'+str(i)+'时.png')
# Out:
# 5620
