# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.style.use({'figure.figsize':(30, 15)})
f=open('C++np/cmake-build-debug/new_data.txt')
val=[]
for line in f.readlines():
    line=line.strip('\n').split(' ')
    a=[]
    for i in line:
        a.append(int(i))
    val.append(a)
index=[]
for i in range(60):
    index.append(i)
val_h=val[13]
p=sns.barplot(x=index,y=val_h)
plt.savefig('ok.png')
