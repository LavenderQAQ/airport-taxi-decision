# %%
import pandas as pd
df=pd.read_excel('20190915长沙.xls')
df
# Out:
#         0       1      2      3       4
# 0    海南航空  HU7135  18:05  20:30     90%
# 1    南方航空  CZ3164  18:05  20:45     83%
# 2    中国国航  CA1349  19:25  22:00     93%
# 3    南方航空  CZ5058  22:10  00:40     90%
# 4    厦门航空  MF8148  22:10  00:40     90%
# ..    ...     ...    ...    ...     ...
# 120  南方航空  CZ6599  19:50  20:40  90.00%
# 121  幸福航空  JR1626  20:55  22:05  70.00%
# 122  海南航空  HU7558  18:45  20:10     70%
# 123  东方航空  MU2966  20:45  22:10     47%
# 124  吉祥航空  HO1706  19:25  20:55     93%
#
# [125 rows x 5 columns]

# %%
df.to_excel('20190915上海(查重后).xls')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-8e4610916c97> in <module>
# ----> 1 df=df.drop_duplicates(subset=['2','3','4'],keep='last')
#       2 df.to_excel('20190915上海(查重后).xls')
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in drop_duplicates(self, subset, keep, inplace)
#    4892
#    4893         inplace = validate_bool_kwarg(inplace, "inplace")
# -> 4894         duplicated = self.duplicated(subset, keep=keep)
#    4895
#    4896         if inplace:
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in duplicated(self, subset, keep)
#    4949         diff = Index(subset).difference(self.columns)
#    4950         if not diff.empty:
# -> 4951             raise KeyError(diff)
#    4952
#    4953         vals = (col.values for name, col in self.items() if name in subset)
#
# KeyError: Index(['2', '3', '4'], dtype='object')
