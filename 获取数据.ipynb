# %%
import pandas as pd
import requests
import json

table=[]

city = {'阿尔山': 'YIE', '阿克苏': 'AKU', '阿拉善右旗': 'RHT', '阿拉善左旗': 'AXF', '阿勒泰': 'AAT', '阿里': 'NGQ', '澳门': 'MFM',
            '安庆': 'AQG', '安顺': 'AVA', '鞍山': 'AOG', '巴彦淖尔': 'RLK', '百色': 'AEB', '包头': 'BAV', '保山': 'BSD', '北海': 'BHY',
            '北京': 'BJS', '白城': 'DBC', '白山': 'NBS', '毕节': 'BFJ', '博乐': 'BPL', '重庆': 'CKG', '昌都': 'BPX', '常德': 'CGD',
            '常州': 'CZX', '朝阳': 'CHG', '成都': 'CTU', '池州': 'JUH', '赤峰': 'CIF', '揭阳': 'SWA', '长春': 'CGQ', '长沙': 'CSX',
            '长治': 'CIH', '承德': 'CDE', '沧源': 'CWJ', '达县': 'DAX', '大理': 'DLU', '大连': 'DLC', '大庆': 'DQA', '大同': 'DAT',
            '丹东': 'DDG', '稻城': 'DCY', '东营': 'DOY', '敦煌': 'DNH', '芒市': 'LUM', '额济纳旗': 'EJN', '鄂尔多斯': 'DSN', '恩施': 'ENH',
            '二连浩特': 'ERL', '佛山': 'FUO', '福州': 'FOC', '抚远': 'FYJ', '阜阳': 'FUG', '赣州': 'KOW', '格尔木': 'GOQ', '固原': 'GYU',
            '广元': 'GYS', '广州': 'CAN', '贵阳': 'KWE', '桂林': 'KWL', '哈尔滨': 'HRB', '哈密': 'HMI', '海口': 'HAK', '海拉尔': 'HLD',
            '邯郸': 'HDG', '汉中': 'HZG', '杭州': 'HGH', '合肥': 'HFE', '和田': 'HTN', '黑河': 'HEK', '呼和浩特': 'HET', '淮安': 'HIA',
            '怀化': 'HJJ', '黄山': 'TXN', '惠州': 'HUZ', '鸡西': 'JXA', '济南': 'TNA', '济宁': 'JNG', '加格达奇': 'JGD', '佳木斯': 'JMU',
            '嘉峪关': 'JGN', '金昌': 'JIC', '金门': 'KNH', '锦州': 'JNZ', '嘉义': 'CYI', '西双版纳': 'JHG', '建三江': 'JSJ', '晋江': 'JJN',
            '井冈山': 'JGS', '景德镇': 'JDZ', '九江': 'JIU', '九寨沟': 'JZH', '喀什': 'KHG', '凯里': 'KJH', '康定': 'KGT', '克拉玛依': 'KRY',
            '库车': 'KCA', '库尔勒': 'KRL', '昆明': 'KMG', '拉萨': 'LXA', '兰州': 'LHW', '黎平': 'HZH', '丽江': 'LJG', '荔波': 'LLB',
            '连云港': 'LYG', '六盘水': 'LPF', '临汾': 'LFQ', '林芝': 'LZY', '临沧': 'LNJ', '临沂': 'LYI', '柳州': 'LZH', '泸州': 'LZO',
            '洛阳': 'LYA', '吕梁': 'LLV', '澜沧': 'JMJ', '龙岩': 'LCX', '满洲里': 'NZH', '梅州': 'MXZ', '绵阳': 'MIG', '漠河': 'OHE',
            '牡丹江': 'MDG', '马祖': 'MFK', '南昌': 'KHN', '南充': 'NAO', '南京': 'NKG', '南宁': 'NNG', '南通': 'NTG', '南阳': 'NNY',
            '宁波': 'NGB', '宁蒗': 'NLH', '攀枝花': 'PZI', '普洱': 'SYM', '齐齐哈尔': 'NDG', '黔江': 'JIQ', '且末': 'IQM', '秦皇岛': 'BPE',
            '青岛': 'TAO', '庆阳': 'IQN', '衢州': 'JUZ', '日喀则': 'RKZ', '日照': 'RIZ', '三亚': 'SYX', '厦门': 'XMN', '上海': 'SHA',
            '深圳': 'SZX', '神农架': 'HPG', '沈阳': 'SHE', '石家庄': 'SJW', '塔城': 'TCG', '台州': 'HYN', '太原': 'TYN', '扬州': 'YTY',
            '唐山': 'TVS', '腾冲': 'TCZ', '天津': 'TSN', '天水': 'THQ', '通辽': 'TGO', '铜仁': 'TEN', '吐鲁番': 'TLQ', '万州': 'WXN',
            '威海': 'WEH', '潍坊': 'WEF', '温州': 'WNZ', '文山': 'WNH', '乌海': 'WUA', '乌兰浩特': 'HLH', '乌鲁木齐': 'URC', '无锡': 'WUX',
            '梧州': 'WUZ', '武汉': 'WUH', '武夷山': 'WUS', '西安': 'SIA', '西昌': 'XIC', '西宁': 'XNN', '锡林浩特': 'XIL',
            '香格里拉(迪庆)': 'DIG',
            '襄阳': 'XFN', '兴义': 'ACX', '徐州': 'XUZ', '香港': 'HKG', '烟台': 'YNT', '延安': 'ENY', '延吉': 'YNJ', '盐城': 'YNZ',
            '伊春': 'LDS',
            '伊宁': 'YIN', '宜宾': 'YBP', '宜昌': 'YIH', '宜春': 'YIC', '义乌': 'YIW', '银川': 'INC', '永州': 'LLF', '榆林': 'UYN',
            '玉树': 'YUS',
            '运城': 'YCU', '湛江': 'ZHA', '张家界': 'DYG', '张家口': 'ZQZ', '张掖': 'YZY', '昭通': 'ZAT', '郑州': 'CGO', '中卫': 'ZHY',
            '舟山': 'HSN',
            '珠海': 'ZUH', '遵义(茅台)': 'WMT', '遵义(新舟)': 'ZYI'}

def cal(dcity, acity, date):
    date = date[0:4] + '-' + date[4:6] + '-' + date[6:8]

    headers = {
        "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.100 Safari/537.36",
        "Content-Type": "application/json",  # 声明文本类型为 json 格式,
        'Cookie': '__DAYU_PP=fbffA7JMjfFQYEJvq3yV285fa84ef3bb; _abtest_userid=14f10ca5-5fe5-4b90-8994-a9a2a8289725; _ga=GA1.2.1823657567.1547218198; _RSG=jB4_phNRhw9fNvhoLy8_29; _RDG=28f1ebd8af073928c800c3c3726b485bce; _RGUID=9eab6d7a-f3fc-42ed-90bf-23c572af95e9; _geoinfo=CN%26%e6%b7%b1%e5%9c%b3; _bfa=1.1547218195619.296wjo.1.1547625090247.1554179025352.5.60; _bfs=1.1; Hm_lvt_cdce8cda34e84469b1c8015204129522=1554179026; Hm_lpvt_cdce8cda34e84469b1c8015204129522=1554179026; gad_city=31f35a60e938dff697ddea628b5bea7c; _RF1=14.153.237.134; Session=SmartLinkCode=U155952&SmartLinkKeyWord=&SmartLinkQuary=&SmartLinkHost=&SmartLinkLanguage=zh; _gid=GA1.2.1875696831.1554179028; _gat=1; Mkt_UnionRecord=%5B%7B%22aid%22%3A%224897%22%2C%22timestamp%22%3A1554179028552%7D%5D; _jzqco=%7C%7C%7C%7C1547625095764%7C1.1997966906.1547218199380.1547636825575.1554179028593.1547636825575.1554179028593.0.0.0.59.59; __zpspc=9.5.1554179028.1554179028.1%232%7Csp0.baidu.com%7C%7C%7C%25E6%2590%25BA%25E7%25A8%258B%7C%23; MKT_Pagesource=PC; Union=OUID=index&AllianceID=4897&SID=155952&SourceID=&Expires=1554783828996; MKT_OrderClick=ASID=4897155952&CT=1554179029004&CURL=https%3A%2F%2Fwww.ctrip.com%2F%3Fsid%3D155952%26allianceid%3D4897%26ouid%3Dindex&VAL={"pc_vid":"1547218195619.296wjo"}; _bfi=p1%3D100101991%26p2%3D100101991%26v1%3D60%26v2%3D59'
    }
    

    url = 'https://flights.ctrip.com/itinerary/api/12808/products'
    request_payload = {"flightWay": "Oneway",
                       "army": "false",
                       "classType": "ALL",
                       "hasChild": 'false',
                       "hasBaby": 'false',
                       "searchIndex": 1,
                       "portingToken": "3fec6a5a249a44faba1f245e61e2af88",
                       "airportParams": [
                           {"dcity": city.get(dcity), "acity": city.get(acity), "dcityname": dcity, "acityname": acity,
                            "date": date}]}

    # 这里传进去的参数必须为 json 格式
    response = requests.post(url, data=json.dumps(request_payload), headers=headers).text
    routeList = json.loads(response)["data"].get('routeList')
    # print("123",routeList)
    for route in routeList:
        if len(route.get('legs')) == 1:
            info = []
            legs = route.get('legs')[0]
            flight = legs.get('flight')
            info.append(flight.get('airlineName'))
            info.append(flight.get('flightNumber'))
            info.append(flight.get('departureDate')[-8:-3])
            info.append(flight.get('arrivalDate')[-8:-3])
            info.append(flight.get('punctualityRate'))
            info.append(legs.get('characteristic').get('lowestPrice'))
            print(info)
            table.append(info)


if __name__ == "__main__":
    acity = '杭州'
    date = '20190915'
    for i in city.keys():
        print(i)
        try:
            if i != acity:
                cal(i, acity, date)
        except Exception:
            continue
    df=pd.DataFrame(table)
    df.to_excel('20190915杭州萧山国际机场.xls')
# Out:
# 阿尔山
# 阿克苏
# 阿拉善右旗
# 没抓到
# 阿拉善左旗
# 阿勒泰
# 阿里
# 没抓到
# 澳门
# 没抓到
# 安庆
# 安顺
# 鞍山
# 巴彦淖尔
# 百色
# 包头
# 保山
# 北海
# ['东方航空', 'MU2754', '12:10', '13:45', '98.32%', 490]
# ['南方航空', 'CZ3147', '14:50', '16:30', '96.61%', 400]
# ['厦门航空', 'MF7094', '15:15', '17:05', '89.44%', 450]
# ['河北航空', 'NS3322', '15:15', '17:05', '89.44%', 402]
# 北京
# ['南方航空', 'CZ6600', '06:25', '09:10', '98.32%', 1480]
# ['南方航空', 'CZ6137', '06:30', '09:20', '100.00%', 950]
# ['中国国航', 'CA1343', '07:05', '09:40', '100.00%', 1480]
# ['海南航空', 'HU7635', '07:35', '10:15', '100.00%', 1905]
# ['南方航空', 'CZ3124', '10:50', '13:25', '96.61%', 3000]
# ['中国国航', 'CA1373', '13:05', '15:35', '89.44%', 1480]
# ['南方航空', 'CZ3718', '14:00', '16:35', '96.61%', 1240]
# ['南方航空', 'CZ3128', '15:45', '18:25', '93.10%', 950]
# ['中国国航', 'CA1363', '16:05', '18:35', '93.10%', 1480]
# ['南方航空', 'CZ3164', '18:05', '20:45', '89.44%', 1480]
# ['中国国航', 'CA1349', '19:25', '22:00', '96.61%', 1480]
# ['南方航空', 'CZ3142', '20:55', '23:35', '63.25%', 730]
# ['厦门航空', 'MF8148', '22:10', '00:40', '93.10%', 800]
# ['南方航空', 'CZ5058', '22:10', '00:40', '93.10%', 800]
# ['海南航空', 'HU7835', '23:05', '01:40', '100.00%', 1480]
# 白城
# 白山
# 毕节
# 博乐
# 重庆
# ['西部航空', 'PN6339', '06:35', '08:05', '100%', 364]
# ['四川航空', '3U8361', '07:30', '09:05', '100%', 700]
# ['南方航空', 'CZ8153', '08:05', '09:30', '100%', 540]
# ['南方航空', 'CZ5179', '08:00', '09:35', '100%', 710]
# ['厦门航空', 'MF8420', '08:00', '09:35', '100%', 560]
# ['四川航空', '3U8951', '13:00', '14:20', '87%', 810]
# ['西部航空', 'PN6231', '16:05', '17:35', '97%', 484]
# ['奥凯航空', 'BK2738', '19:15', '20:50', '93%', 370]
# ['西藏航空', 'TV6483', '20:05', '21:30', '97%', 408]
# ['中国国航', 'CA4597', '20:05', '21:30', '97%', 380]
# ['华夏航空', 'G58119', '20:05', '21:30', '97%', 560]
# ['南方航空', 'CZ8053', '20:35', '21:55', '70%', 410]
# ['海南航空', 'HU7410', '23:00', '00:20', '93%', 345]
# ['华夏航空', 'G52763', '14:50', '17:50', '90%', 790]
# ['重庆航空', 'OQ2353', '08:05', '09:30', '100%', 585]
# ['重庆航空', 'OQ2053', '20:35', '21:55', '70%', 407]
# 昌都
# 常德
# 常州
# ['南方航空', 'CZ6407', '10:40', '12:30', '81.65%', 850]
# 朝阳
# 成都
# ['成都航空', 'EU7067', '07:00', '09:00', '100%', 1130]
# ['东方航空', 'MU3923', '07:00', '09:00', '100%', 1070]
# ['四川航空', '3U8997', '07:00', '09:00', '100%', 1020]
# ['成都航空', 'EU1801', '07:35', '09:35', '97%', 1085]
# ['昆明航空', 'KY3020', '11:45', '13:40', '93%', 1910]
# ['深圳航空', 'ZH5390', '11:45', '13:40', '93%', 4410]
# ['中国国航', 'CA4371', '19:10', '21:10', '97%', 1210]
# ['西藏航空', 'TV6385', '19:10', '21:10', '97%', 1210]
# ['奥凯航空', 'BK2780', '21:55', '23:50', '90%', 562]
# ['南方航空', 'CZ3462', '22:50', '00:50', '83%', 490]
# ['成都航空', 'EU1807', '23:05', '01:05', '90%', 460]
# ['南方航空', 'CZ3808', '12:40', '16:15', '97%', 830]
# 池州
# 赤峰
# 揭阳
# ['南方航空', 'CZ8154', '12:50', '14:20', '80%', 660]
# ['南方航空', 'CZ6745', '13:25', '14:55', '90%', 610]
# ['山东航空', 'SC4092', '14:10', '15:45', '80%', 500]
# ['南方航空', 'CZ8054', '15:20', '16:55', '83%', 520]
# ['东方航空', 'MU2400', '18:25', '20:05', '87%', 640]
# ['成都航空', 'EU2284', '21:50', '23:25', '67%', 350]
# ['重庆航空', 'OQ2354', '12:50', '14:20', '80%', 652]
# ['重庆航空', 'OQ2054', '15:20', '16:55', '83%', 524]
# 长春
# ['南方航空', 'CZ6768', '08:20', '11:35', '87%', 2250]
# ['首都航空', 'JD5766', '15:15', '18:40', '80%', 2240]
# ['厦门航空', 'MF8054', '13:15', '18:00', '87%', 1220]
# ['南方航空', 'CZ3938', '19:00', '00:30', '67%', 890]
# ['海南航空', 'HU7450', '20:10', '01:25', '77%', 670]
# ['昆明航空', 'KY3032', '20:45', '01:25', '60%', 882]
# 长沙
# 长治
# 承德
# 沧源
# 达县
# 大理
# ['东方航空', 'MU9734', '08:55', '11:15', '98.32%', 1260]
# 大连
# ['海南航空', 'HU7557', '07:05', '10:00', '98.32%', 970]
# ['南方航空', 'CZ6427', '10:15', '13:10', '83.67%', 1790]
# ['厦门航空', 'MF8074', '18:30', '21:25', '77.46%', 750]
# ['中国国航', 'CA8961', '06:50', '11:05', '94.87%', 740]
# ['奥凯航空', 'BK2842', '13:00', '17:35', '85.63%', 845]
# ['厦门航空', 'MF8036', '13:10', '17:25', '96.61%', 970]
# 大庆
# 大同
# ['深圳航空', 'ZH5392', '21:00', '00:45', '83%', 740]
# ['昆明航空', 'KY3022', '21:00', '00:45', '83%', 470]
# 丹东
# 稻城
# 东营
# 敦煌
# ['成都航空', 'EU2298', '17:50', '22:55', '97%', 640]
# ['四川航空', '3U1630', '17:50', '22:55', '97%', 1140]
# 芒市
# ['瑞丽航空', 'DR5335', '18:50', '21:20', '96.61%', 660]
# 额济纳旗
# 鄂尔多斯
# ['东方航空', 'MU7363', '15:40', '18:05', '77%', 750]
# 恩施
# 二连浩特
# 佛山
# 福州
# ['厦门航空', 'MF8433', '07:20', '08:50', '83%', 920]
# ['厦门航空', 'MF8235', '09:15', '10:45', '80%', 920]
# ['四川航空', '3U8998', '12:15', '13:50', '63%', 1200]
# ['南方航空', 'CZ5178', '18:55', '20:30', '77%', 580]
# ['厦门航空', 'MF8419', '18:55', '20:30', '77%', 590]
# 抚远
# 阜阳
# 赣州
# 格尔木
# 固原
# 广元
# 广州
# ['南方航空', 'CZ6177', '08:10', '09:30', '100.00%', 1010]
# ['南方航空', 'CZ3380', '10:20', '11:35', '98.32%', 1280]
# ['南方航空', 'CZ331', '21:30', '22:50', '96.61%', 1280]
# ['南方航空', 'CZ3388', '23:35', '01:05', '96.61%', 1280]
# 贵阳
# ['多彩航空', 'GY7157', '16:50', '20:00', '94.87%', 410]
# 桂林
# 哈尔滨
# ['首都航空', 'JD5122', '18:05', '22:00', '93%', 945]
# ['南方航空', 'CZ3126', '19:50', '23:45', '83%', 1220]
# ['奥凯航空', 'BK2870', '06:55', '12:30', '70%', 1190]
# ['厦门航空', 'MF8040', '08:15', '13:50', '90%', 2240]
# ['海南航空', 'HU7726', '16:30', '22:15', '50%', 2250]
# 哈密
# 海口
# ['海南航空', 'HU7117', '07:00', '08:55', '97%', 238]
# ['海南航空', 'HU7227', '07:15', '09:15', '100%', 318]
# ['首都航空', 'JD5121', '07:20', '09:20', '83%', 305]
# ['天津航空', 'GS6567', '07:50', '09:45', '83%', 244]
# ['南方航空', 'CZ6759', '09:25', '11:20', '77%', 350]
# ['南方航空', 'CZ6767', '13:50', '15:55', '80%', 320]
# ['东方航空', 'MU5682', '13:55', '15:50', '80%', 290]
# ['海南航空', 'HU7297', '14:05', '16:00', '80%', 315]
# ['海南航空', 'HU7389', '14:50', '16:50', '87%', 315]
# ['东海航空', 'DZ6290', '16:00', '17:55', '60%', 250]
# ['海南航空', 'HU484', '18:10', '20:10', '63%', 1410]
# ['海南航空', 'HU7773', '22:50', '00:50', '100%', 225]
# ['南方航空', 'CZ6745', '11:10', '14:55', '90%', 510]
# ['九元航空', 'AQ1118', '11:30', '15:10', '87%', 199]
# ['九元航空', 'AQ1282', '20:25', '22:25', '', 159]
# 海拉尔
# ['成都航空', 'EU1824', '17:55', '23:55', '70%', 697]
# ['四川航空', '3U1602', '17:55', '23:55', '70%', 1350]
# ['青岛航空', 'QW6076', '18:00', '00:25', '93%', 623]
# 邯郸
# 汉中
# 杭州
# ['南方航空', 'CZ5084', '07:10', '08:50', '97%', 980]
# ['厦门航空', 'MF8229', '07:10', '08:50', '97%', 990]
# ['海南航空', 'HU7451', '07:20', '09:00', '77%', 900]
# ['南方航空', 'CZ5004', '18:40', '20:35', '63%', 500]
# ['厦门航空', 'MF8026', '18:40', '20:35', '63%', 450]
# 合肥
# 和田
# 黑河
# 呼和浩特
# ['厦门航空', 'MF8040', '11:25', '13:50', '94.87%', 1000]
# ['南方航空', 'CZ3720', '14:30', '16:45', '85.63%', 690]
# ['厦门航空', 'MF8138', '15:05', '17:20', '63.25%', 600]
# ['南方航空', 'CZ6760', '16:30', '19:05', '81.65%', 600]
# ['海南航空', 'HU7450', '23:05', '01:25', '87.56%', 445]
# ['华夏航空', 'G52705', '08:15', '12:15', '91.29%', 510]
# 淮安
# ['厦门航空', 'MF8564', '19:40', '21:35', '77%', 840]
# 怀化
# 黄山
# 惠州
# 鸡西
# 济南
# ['山东航空', 'SC2193', '07:25', '09:45', '100.00%', 440]
# ['山东航空', 'SC4091', '08:40', '10:50', '98.32%', 620]
# ['中国国航', 'CA8961', '08:50', '11:05', '94.87%', 670]
# ['海南航空', 'HU7528', '10:15', '12:25', '96.61%', 865]
# ['海南航空', 'HU7228', '13:45', '15:45', '94.87%', 680]
# ['厦门航空', 'MF8036', '15:25', '17:25', '98.32%', 690]
# ['南方航空', 'CZ3926', '16:45', '18:55', '91.29%', 630]
# ['成都航空', 'EU2734', '17:15', '19:15', '83.67%', 530]
# ['山东航空', 'SC4786', '18:30', '20:40', '98.32%', 440]
# ['中国国航', 'CA4786', '18:30', '20:40', '98.32%', 630]
# ['西藏航空', 'TV6780', '18:30', '20:40', '98.32%', 710]
# ['成都航空', 'EU1824', '21:55', '23:55', '83.67%', 400]
# ['四川航空', '3U1602', '21:55', '23:55', '83.67%', 690]
# ['天津航空', 'GS9878', '19:00', '23:10', '96.61%', 575]
# ['北部湾航空', 'GX7878', '19:00', '23:10', '96.61%', 529]
# 济宁
# ['北部湾航空', 'GX8930', '16:20', '18:10', '98.32%', 730]
# 加格达奇
# 佳木斯
# 嘉峪关
# 金昌
# 金门
# 没抓到
# 锦州
# 嘉义
# 没抓到
# 西双版纳
# ['深圳航空', 'ZH5400', '15:40', '18:10', '90%', 770]
# ['昆明航空', 'KY3030', '15:40', '18:10', '90%', 767]
# ['昆明航空', 'KY3028', '22:20', '00:45', '90%', 687]
# ['深圳航空', 'ZH5398', '22:20', '00:45', '90%', 770]
# ['春秋航空', '9C8852', '18:10', '20:50', '90%', 580]
# 建三江
# 晋江
# ['厦门航空', 'MF8137', '08:50', '10:25', '83.67%', 560]
# ['深圳航空', 'ZH8767', '09:20', '10:55', '83.67%', 560]
# ['厦门航空', 'MF8249', '14:15', '15:50', '89.44%', 560]
# ['昆明航空', 'KY9201', '09:20', '10:55', '83.67%', 564]
# 井冈山
# 景德镇
# 九江
# 九寨沟
# 喀什
# 凯里
# 康定
# 克拉玛依
# 库车
# 库尔勒
# 昆明
# ['四川航空', '3U8929', '07:50', '10:00', '100%', 530]
# ['成都航空', 'EU7059', '07:50', '10:00', '100%', 690]
# ['东方航空', 'MU3993', '07:50', '10:00', '100%', 760]
# ['东方航空', 'MU5749', '13:10', '15:15', '100%', 1030]
# ['天津航空', 'GS6574', '14:05', '16:00', '87%', 577]
# ['东方航空', 'MU9398', '16:10', '18:15', '83%', 770]
# ['上海航空', 'FM9398', '16:10', '18:15', '83%', 680]
# ['南方航空', 'CZ6428', '17:45', '19:50', '73%', 690]
# ['西藏航空', 'TV6046', '20:20', '22:20', '97%', 561]
# ['东方航空', 'MU5828', '21:20', '23:20', '100%', 580]
# ['南方航空', 'CZ3468', '21:30', '23:35', '100%', 540]
# ['海南航空', 'HU7460', '23:00', '01:00', '93%', 455]
# ['昆明航空', 'KY8287', '08:25', '13:55', '97.70%', 1369]
# 拉萨
# ['中国国航', 'CA3983', '16:55', '20:25', '93%', 1610]
# ['西藏航空', 'TV9933', '16:55', '20:25', '93%', 1590]
# ['东方航空', 'MU5828', '17:30', '23:20', '100.00%', 1740]
# 兰州
# ['乌鲁木齐航空', 'UQ2519', '11:15', '13:45', '93%', 503]
# ['东方航空', 'MU2399', '12:20', '14:40', '100%', 3830]
# ['厦门航空', 'MF8202', '18:40', '21:00', '77%', 460]
# ['南方航空', 'CZ6930', '19:05', '21:20', '100%', 610]
# ['青岛航空', 'QW6072', '20:00', '22:30', '90%', 415]
# ['九元航空', 'AQ1126', '12:00', '14:30', '', 519]
# 黎平
# ['幸福航空', 'JR1630', '10:20', '12:00', '97%', 894]
# 丽江
# ['吉祥航空', 'HO1072', '10:40', '13:00', '97%', 658]
# ['东方航空', 'MU4880', '10:40', '13:00', '97%', 753]
# ['中国国航', 'CA4067', '11:10', '13:15', '97%', 620]
# ['成都航空', 'EU2721', '22:10', '00:25', '87%', 610]
# ['首都航空', 'JD5883', '06:25', '08:40', '97%', 1706]
# 荔波
# 连云港
# ['厦门航空', 'MF8054', '16:00', '18:00', '87%', 750]
# 六盘水
# 临汾
# ['海南航空', 'HU7676', '14:25', '16:15', '47%', 610]
# 林芝
# 临沧
# 临沂
# ['天津航空', 'GS8976', '20:45', '23:00', '81.65%', 644]
# ['北部湾航空', 'GX8976', '20:45', '23:00', '81.65%', 650]
# 柳州
# 泸州
# ['厦门航空', 'MF8250', '19:30', '21:10', '87%', 420]
# 洛阳
# 吕梁
# ['青岛航空', 'QW6076', '22:15', '00:25', '93%', 505]
# 澜沧
# 龙岩
# 满洲里
# ['成都航空', 'EU2734', '13:30', '19:15', '83.67%', 2710]
# 梅州
# ['南方航空', 'CZ6566', '14:10', '15:40', '96.61%', 510]
# 绵阳
# ['西藏航空', 'TV9909', '07:00', '08:45', '97%', 700]
# ['中国国航', 'CA3969', '07:00', '08:45', '97%', 720]
# ['厦门航空', 'MF8434', '12:45', '14:30', '33%', 1200]
# 漠河
# 牡丹江
# 马祖
# 没抓到
# 南昌
# 南充
# 南京
# ['东方航空', 'MU2753', '06:55', '08:45', '100.00%', 870]
# ['成都航空', 'EU2754', '10:05', '11:50', '96.61%', 589]
# ['厦门航空', 'MF8556', '10:50', '12:25', '94.87%', 570]
# ['东方航空', 'MU2727', '13:50', '15:25', '98.32%', 730]
# ['昆明航空', 'KY9785', '18:10', '19:55', '96.61%', 890]
# ['深圳航空', 'ZH9585', '18:10', '19:55', '96.61%', 890]
# 南宁
# ['海南航空', 'HU7452', '12:30', '14:05', '83.67%', 420]
# ['南方航空', 'CZ8683', '12:25', '14:10', '98.32%', 560]
# ['昆明航空', 'KY9558', '15:40', '17:30', '83.67%', 510]
# ['中国国航', 'CA3858', '15:40', '17:30', '83.67%', 530]
# ['深圳航空', 'ZH9558', '15:40', '17:30', '83.67%', 510]
# 南通
# ['东海航空', 'DZ6289', '09:45', '11:45', '97%', 1040]
# 南阳
# 宁波
# ['长龙航空', 'GJ8665', '09:20', '11:10', '88.85%', 368]
# ['海南航空', 'HU7334', '11:20', '13:05', '91.29%', 395]
# ['西部航空', 'PN6340', '11:30', '13:20', '93.10%', 384]
# ['海南航空', 'HU7466', '13:05', '14:45', '98.32%', 395]
# ['南方航空', 'CZ8752', '17:50', '19:40', '75.28%', 360]
# ['长龙航空', 'GJ8671', '22:35', '00:15', '89.44%', 308]
# 宁蒗
# 攀枝花
# 普洱
# 齐齐哈尔
# 黔江
# ['南方航空', 'CZ3808', '15:05', '16:15', '97%', 710]
# 且末
# 秦皇岛
# 青岛
# ['山东航空', 'SC8737', '08:25', '11:00', '94.87%', 640]
# ['中国国航', 'CA8737', '08:25', '11:00', '94.87%', 790]
# ['厦门航空', 'MF8395', '10:50', '13:35', '96.61%', 870]
# ['奥凯航空', 'BK2770', '16:05', '18:45', '96.61%', 620]
# ['山东航空', 'SC4753', '19:10', '21:35', '93.10%', 550]
# ['南方航空', 'CZ3938', '21:55', '00:30', '81.65%', 450]
# 庆阳
# 衢州
# 日喀则
# 日照
# ['天津航空', 'GS9878', '20:50', '23:10', '96.61%', 414]
# ['北部湾航空', 'GX7878', '20:50', '23:10', '96.61%', 389]
# 三亚
# ['首都航空', 'JD5765', '07:10', '09:25', '90%', 280]
# ['首都航空', 'JD5597', '08:45', '11:05', '80%', 485]
# ['海南航空', 'HU7169', '13:20', '15:35', '83%', 490]
# ['大新华航空', 'CN7169', '13:20', '15:35', '83%', 490]
# ['东方航空', 'MU2920', '14:25', '16:30', '67%', 690]
# ['四川航空', '3U1650', '15:45', '18:05', '57%', 770]
# ['成都航空', 'EU2752', '15:45', '18:05', '57%', 330]
# ['厦门航空', 'MF8396', '17:45', '19:45', '63%', 290]
# ['东方航空', 'MU2728', '19:30', '21:45', '83%', 500]
# ['南方航空', 'CZ3944', '22:45', '00:55', '90%', 250]
# 厦门
# ['厦门航空', 'MF8609', '06:50', '08:40', '96.61%', 440]
# ['西藏航空', 'TV6779', '07:10', '08:55', '100.00%', 640]
# ['山东航空', 'SC4785', '07:10', '08:55', '100.00%', 440]
# ['中国国航', 'CA4785', '07:10', '08:55', '100.00%', 560]
# ['厦门航空', 'MF8201', '12:40', '14:15', '94.87%', 1150]
# ['厦门航空', 'MF8333', '15:30', '17:10', '94.87%', 620]
# ['四川航空', '3U8952', '17:50', '19:35', '79.58%', 480]
# ['西部航空', 'PN6232', '21:20', '22:55', '89.44%', 294]
# ['厦门航空', 'MF8504', '22:20', '23:55', '91.29%', 300]
# 上海
# ['东方航空', 'MU9227', '07:05', '09:05', '100.00%', 920]
# ['上海航空', 'FM9227', '07:05', '09:05', '100.00%', 920]
# ['吉祥航空', 'HO1123', '07:15', '09:10', '98.32%', 690]
# ['东方航空', 'MU4713', '07:15', '09:10', '98.32%', 723]
# ['南方航空', 'CZ3239', '07:25', '09:25', '83%', 450]
# ['东方航空', 'MU5363', '08:05', '10:05', '', 1660]
# ['东方航空', 'MU9397', '09:35', '11:40', '90%', 1330]
# ['上海航空', 'FM9397', '09:35', '11:40', '90%', 1330]
# ['上海航空', 'FM9399', '10:15', '12:15', '89.44%', 1490]
# ['东方航空', 'MU9399', '10:15', '12:15', '89.44%', 1490]
# ['东方航空', 'MU9391', '11:20', '13:10', '98.32%', 1330]
# ['上海航空', 'FM9391', '11:20', '13:10', '98.32%', 1330]
# ['东方航空', 'MU4711', '13:00', '14:45', '89.44%', 803]
# ['吉祥航空', 'HO1125', '13:00', '14:45', '89.44%', 740]
# ['东方航空', 'MU5271', '14:05', '15:55', '94.87%', 1100]
# ['东方航空', 'MU4879', '15:40', '17:40', '93%', 955]
# ['吉祥航空', 'HO1071', '15:40', '17:40', '93%', 920]
# ['南方航空', 'CZ3968', '16:15', '18:25', '100%', 600]
# ['上海航空', 'FM9361', '16:50', '18:40', '75.28%', 1250]
# ['东方航空', 'MU9361', '16:50', '18:40', '75.28%', 1250]
# ['东方航空', 'MU9395', '18:45', '20:35', '89.44%', 1250]
# ['上海航空', 'FM9395', '18:45', '20:35', '89.44%', 1250]
# ['金鹏航空', 'Y87488', '20:15', '22:35', '93%', 510]
# ['海南航空', 'HU7488', '20:15', '22:35', '93%', 405]
# ['南方航空', 'CZ3970', '20:55', '23:05', '87%', 450]
# ['东方航空', 'MU5367', '21:40', '23:40', '93%', 710]
# ['春秋航空', '9C8851', '11:45', '13:55', '100%', 410]
# 深圳
# 神农架
# 沈阳
# ['昆明航空', 'KY3026', '11:40', '15:15', '90%', 1098]
# ['瑞丽航空', 'DR6575', '16:00', '19:25', '90%', 838]
# ['首都航空', 'JD5139', '17:30', '21:05', '73%', 1125]
# ['南方航空', 'CZ6407', '07:35', '12:30', '67%', 1660]
# ['中国国航', 'CA3515', '09:55', '15:20', '73%', 4830]
# ['深圳航空', 'ZH9717', '09:55', '15:20', '73%', 1890]
# ['奥凯航空', 'BK2770', '13:00', '18:45', '93%', 1950]
# ['厦门航空', 'MF8026', '14:45', '20:35', '63%', 2100]
# ['南方航空', 'CZ5004', '14:45', '20:35', '63%', 2100]
# ['海南航空', 'HU7330', '19:05', '23:50', '87%', 2100]
# 石家庄
# ['河北航空', 'NS3321', '09:40', '11:45', '87.56%', 732]
# ['昆明航空', 'KY3032', '23:30', '01:25', '79.58%', 535]
# 塔城
# 台州
# 太原
# ['东方航空', 'MU5681', '08:00', '09:55', '98.32%', 580]
# ['海南航空', 'HU7298', '08:15', '10:15', '94.87%', 665]
# ['厦门航空', 'MF8174', '10:40', '12:45', '96.61%', 880]
# ['奥凯航空', 'BK2842', '15:40', '17:35', '85.63%', 650]
# ['海南航空', 'HU7330', '21:55', '23:50', '93.10%', 445]
# ['深圳航空', 'ZH5392', '22:50', '00:45', '91.29%', 650]
# ['昆明航空', 'KY3022', '22:50', '00:45', '91.29%', 407]
# ['北部湾航空', 'GX8930', '14:00', '18:10', '98.32%', 639]
# ['天津航空', 'GS8930', '14:00', '18:10', '98.32%', 725]
# 扬州
# 唐山
# 腾冲
# 天津
# ['奥凯航空', 'BK2931', '10:30', '13:05', '70%', 1520]
# ['奥凯航空', 'BK2903', '14:10', '16:35', '83%', 1110]
# ['中国国航', 'CA1669', '17:05', '19:30', '70%', 920]
# ['华夏航空', 'G58041', '17:05', '19:30', '70%', 965]
# ['海南航空', 'HU7726', '19:45', '22:15', '50%', 820]
# ['厦门航空', 'MF8194', '20:30', '23:10', '43%', 850]
# ['南方航空', 'CZ3980', '22:45', '01:10', '53%', 540]
# ['海南航空', 'HU7676', '12:05', '16:15', '47%', 1390]
# ['天津航空', 'GS7819', '07:30', '10:05', '100%', 1282]
# 天水
# 通辽
# 铜仁
# ['幸福航空', 'JR1632', '20:45', '22:15', '87%', 266]
# 吐鲁番
# ['南方航空', 'CZ6178', '15:55', '20:00', '93.10%', 860]
# 万州
# ['北部湾航空', 'GX7884', '11:10', '12:55', '98.32%', 460]
# 威海
# 潍坊
# ['北部湾航空', 'GX8986', '11:00', '13:25', '93.54%', 730]
# 温州
# ['四川航空', '3U8362', '12:20', '14:00', '90%', 550]
# ['吉祥航空', 'HO1705', '14:20', '16:05', '87%', 380]
# ['南方航空', 'CZ6956', '16:15', '17:45', '67%', 440]
# ['长龙航空', 'GJ8011', '20:30', '22:10', '73%', 268]
# ['青岛航空', 'QW6077', '22:45', '00:20', '93%', 205]
# 文山
# 乌海
# 乌兰浩特
# 乌鲁木齐
# ['南方航空', 'CZ6955', '08:30', '12:45', '96.61%', 1000]
# ['南方航空', 'CZ8751', '10:05', '14:15', '87.56%', 1820]
# ['海南航空', 'HU7819', '13:50', '17:55', '93.10%', 988]
# ['厦门航空', 'MF8230', '16:05', '20:45', '98.32%', 980]
# ['南方航空', 'CZ5085', '16:05', '20:45', '98.32%', 1520]
# ['奥凯航空', 'BK2776', '21:10', '01:15', '96.61%', 750]
# ['乌鲁木齐航空', 'UQ2519', '07:40', '13:45', '96.61%', 1100]
# ['南方航空', 'CZ6930', '15:30', '21:20', '100.00%', 1520]
# ['南方航空', 'CZ3630', '20:15', '01:55', '96.61%', 960]
# ['天津航空', 'GS7501', '09:00', '13:20', '96.61%', 954]
# 无锡
# ['东方航空', 'MU2919', '07:50', '09:50', '96.61%', 700]
# ['昆明航空', 'KY9557', '10:15', '12:05', '81.65%', 1130]
# ['中国国航', 'CA3857', '10:15', '12:05', '81.65%', 1130]
# ['深圳航空', 'ZH9557', '10:15', '12:05', '81.65%', 1130]
# ['东方航空', 'MU2965', '15:30', '17:20', '81.65%', 740]
# 梧州
# ['上海航空', 'FM9400', '15:35', '17:00', '87%', 770]
# ['东方航空', 'MU9400', '15:35', '17:00', '87%', 1050]
# 武汉
# 没抓到
# 武夷山
# 西安
# ['奥凯航空', 'BK2864', '06:15', '08:20', '100.00%', 410]
# ['南方航空', 'CZ6565', '08:10', '10:10', '100.00%', 530]
# ['厦门航空', 'MF8232', '11:40', '13:40', '98.32%', 630]
# ['南方航空', 'CZ3722', '14:50', '16:45', '100.00%', 630]
# ['东方航空', 'MU2265', '15:50', '17:50', '96.61%', 580]
# ['东方航空', 'MU2383', '17:25', '19:20', '94.87%', 530]
# ['成都航空', 'EU2298', '21:05', '22:55', '98.32%', 470]
# ['四川航空', '3U1630', '21:05', '22:55', '98.32%', 670]
# ['南方航空', 'CZ3948', '21:50', '23:40', '100.00%', 480]
# ['海南航空', 'HU6318', '23:10', '01:15', '98.32%', 405]
# 西昌
# ['四川航空', '3U8049', '15:05', '17:15', '100%', 780]
# ['成都航空', 'EU7007', '15:05', '17:15', '100%', 850]
# 西宁
# ['南方航空', 'CZ8401', '17:15', '19:40', '98.32%', 960]
# ['南方航空', 'CZ3630', '23:30', '01:55', '96.61%', 600]
# ['奥凯航空', 'BK2738', '16:10', '20:50', '100.00%', 650]
# 锡林浩特
# 香格里拉(迪庆)
# ['昆明航空', 'KY8287', '11:10', '13:55', '97.70%', 857]
# 襄阳
# ['幸福航空', 'JR1546', '19:10', '20:55', '97%', 430]
# 兴义
# 徐州
# ['海南航空', 'HU7380', '12:10', '14:00', '97%', 690]
# 香港
# 没抓到
# 烟台
# ['奥凯航空', 'BK2870', '09:55', '12:30', '93.10%', 710]
# ['深圳航空', 'ZH9717', '12:40', '15:20', '85.63%', 900]
# ['中国国航', 'CA3515', '12:40', '15:20', '85.63%', 900]
# ['东方航空', 'MU2061', '19:15', '22:05', '91.29%', 420]
# ['北部湾航空', 'GX8976', '18:50', '23:00', '83.67%', 699]
# ['昆明航空', 'KY9717', '12:40', '15:20', '85.63%', 900]
# 延安
# 延吉
# 盐城
# ['东方航空', 'MU5750', '19:10', '21:05', '87%', 890]
# 伊春
# 伊宁
# 宜宾
# ['多彩航空', 'GY7157', '18:25', '20:00', '94.87%', 650]
# 宜昌
# 没抓到
# 宜春
# 义乌
# 银川
# ['南方航空', 'CZ3952', '11:05', '13:30', '97%', 1040]
# ['厦门航空', 'MF8236', '16:10', '18:50', '97%', 1040]
# ['东方航空', 'MU2265', '13:40', '17:50', '93%', 770]
# 永州
# 榆林
# ['南方航空', 'CZ3722', '12:40', '16:45', '100.00%', 910]
# 玉树
# 运城
# ['昆明航空', 'KY9011', '13:40', '15:20', '85.63%', 680]
# ['深圳航空', 'ZH8177', '13:40', '15:20', '85.63%', 680]
# 湛江
# ['奥凯航空', 'BK2932', '17:10', '19:00', '90%', 754]
# 张家界
# ['幸福航空', 'JR1622', '09:55', '11:00', '98.32%', 240]
# ['南方航空', 'CZ606', '10:35', '11:30', '100.00%', 240]
# ['华夏航空', 'G52705', '11:20', '12:15', '91.29%', 260]
# ['幸福航空', 'JR1624', '13:20', '14:25', '100.00%', 306]
# ['幸福航空', 'JR1554', '15:50', '17:00', '100.00%', 697]
# ['南方航空', 'CZ6599', '19:50', '20:40', '94.87%', 240]
# ['幸福航空', 'JR1626', '20:55', '22:05', '83.67%', 234]
# 张家口
# 张掖
# 昭通
# 郑州
# 没抓到
# 中卫
# 没抓到
# 舟山
# 珠海
# 没抓到
# 遵义(茅台)
# 没抓到
# 遵义(新舟)
# ['天津航空', 'GS7820', '13:40', '15:10', '98.32%', 214]
# ['吉祥航空', 'HO1706', '19:25', '20:55', '90%', 279]

# %%
import pandas as pd
import requests
import json

table=[]

city = { '黎平': 'HZH', '丽江': 'LJG', '荔波': 'LLB',
            '连云港': 'LYG', '六盘水': 'LPF', '临汾': 'LFQ', '林芝': 'LZY', '临沧': 'LNJ', '临沂': 'LYI', '柳州': 'LZH', '泸州': 'LZO',
            '洛阳': 'LYA', '吕梁': 'LLV', '澜沧': 'JMJ', '龙岩': 'LCX', '满洲里': 'NZH', '梅州': 'MXZ', '绵阳': 'MIG', '漠河': 'OHE',
            '牡丹江': 'MDG', '马祖': 'MFK', '南昌': 'KHN', '南充': 'NAO', '南京': 'NKG', '南宁': 'NNG', '南通': 'NTG', '南阳': 'NNY',
            '宁波': 'NGB', '宁蒗': 'NLH', '攀枝花': 'PZI', '普洱': 'SYM', '齐齐哈尔': 'NDG', '黔江': 'JIQ', '且末': 'IQM', '秦皇岛': 'BPE',
            '青岛': 'TAO', '庆阳': 'IQN', '衢州': 'JUZ', '日喀则': 'RKZ', '日照': 'RIZ', '三亚': 'SYX', '厦门': 'XMN', '上海': 'SHA',
            '深圳': 'SZX', '神农架': 'HPG', '沈阳': 'SHE', '石家庄': 'SJW', '塔城': 'TCG', '台州': 'HYN', '太原': 'TYN', '扬州': 'YTY',
            '唐山': 'TVS', '腾冲': 'TCZ', '天津': 'TSN', '天水': 'THQ', '通辽': 'TGO', '铜仁': 'TEN', '吐鲁番': 'TLQ', '万州': 'WXN',
            '威海': 'WEH', '潍坊': 'WEF', '温州': 'WNZ', '文山': 'WNH', '乌海': 'WUA', '乌兰浩特': 'HLH', '乌鲁木齐': 'URC', '无锡': 'WUX',
            '梧州': 'WUZ', '武汉': 'WUH', '武夷山': 'WUS', '西安': 'SIA', '西昌': 'XIC', '西宁': 'XNN', '锡林浩特': 'XIL',
            '香格里拉(迪庆)': 'DIG',
            '襄阳': 'XFN', '兴义': 'ACX', '徐州': 'XUZ', '香港': 'HKG', '烟台': 'YNT', '延安': 'ENY', '延吉': 'YNJ', '盐城': 'YNZ',
            '伊春': 'LDS',
            '伊宁': 'YIN', '宜宾': 'YBP', '宜昌': 'YIH', '宜春': 'YIC', '义乌': 'YIW', '银川': 'INC', '永州': 'LLF', '榆林': 'UYN',
            '玉树': 'YUS',
            '运城': 'YCU', '湛江': 'ZHA', '张家界': 'DYG', '张家口': 'ZQZ', '张掖': 'YZY', '昭通': 'ZAT', '郑州': 'CGO', '中卫': 'ZHY',
            '舟山': 'HSN',
            '珠海': 'ZUH', '遵义(茅台)': 'WMT', '遵义(新舟)': 'ZYI'}

def xiecheng(dcity, acity, date):
    date = date[0:4] + '-' + date[4:6] + '-' + date[6:8]

    headers = {
        "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.100 Safari/537.36",
        "Content-Type": "application/json",  # 声明文本类型为 json 格式,
        'Cookie': '__DAYU_PP=fbffA7JMjfFQYEJvq3yV285fa84ef3bb; _abtest_userid=14f10ca5-5fe5-4b90-8994-a9a2a8289725; _ga=GA1.2.1823657567.1547218198; _RSG=jB4_phNRhw9fNvhoLy8_29; _RDG=28f1ebd8af073928c800c3c3726b485bce; _RGUID=9eab6d7a-f3fc-42ed-90bf-23c572af95e9; _geoinfo=CN%26%e6%b7%b1%e5%9c%b3; _bfa=1.1547218195619.296wjo.1.1547625090247.1554179025352.5.60; _bfs=1.1; Hm_lvt_cdce8cda34e84469b1c8015204129522=1554179026; Hm_lpvt_cdce8cda34e84469b1c8015204129522=1554179026; gad_city=31f35a60e938dff697ddea628b5bea7c; _RF1=14.153.237.134; Session=SmartLinkCode=U155952&SmartLinkKeyWord=&SmartLinkQuary=&SmartLinkHost=&SmartLinkLanguage=zh; _gid=GA1.2.1875696831.1554179028; _gat=1; Mkt_UnionRecord=%5B%7B%22aid%22%3A%224897%22%2C%22timestamp%22%3A1554179028552%7D%5D; _jzqco=%7C%7C%7C%7C1547625095764%7C1.1997966906.1547218199380.1547636825575.1554179028593.1547636825575.1554179028593.0.0.0.59.59; __zpspc=9.5.1554179028.1554179028.1%232%7Csp0.baidu.com%7C%7C%7C%25E6%2590%25BA%25E7%25A8%258B%7C%23; MKT_Pagesource=PC; Union=OUID=index&AllianceID=4897&SID=155952&SourceID=&Expires=1554783828996; MKT_OrderClick=ASID=4897155952&CT=1554179029004&CURL=https%3A%2F%2Fwww.ctrip.com%2F%3Fsid%3D155952%26allianceid%3D4897%26ouid%3Dindex&VAL={"pc_vid":"1547218195619.296wjo"}; _bfi=p1%3D100101991%26p2%3D100101991%26v1%3D60%26v2%3D59'
    }
    

    url = 'https://flights.ctrip.com/itinerary/api/12808/products'
    request_payload = {"flightWay": "Oneway",
                       "army": "false",
                       "classType": "ALL",
                       "hasChild": 'false',
                       "hasBaby": 'false',
                       "searchIndex": 1,
                       "portingToken": "3fec6a5a249a44faba1f245e61e2af88",
                       "airportParams": [
                           {"dcity": city.get(dcity), "acity": city.get(acity), "dcityname": dcity, "acityname": acity,
                            "date": date}]}

    # 这里传进去的参数必须为 json 格式
    response = requests.post(url, data=json.dumps(request_payload), headers=headers).text
    routeList = json.loads(response)["data"].get('routeList')
    # print("123",routeList)
    for route in routeList:
        if len(route.get('legs')) == 1:
            info = []
            legs = route.get('legs')[0]
            flight = legs.get('flight')
            info.append(flight.get('airlineName'))
            info.append(flight.get('flightNumber'))
            info.append(flight.get('departureDate')[-8:-3])
            info.append(flight.get('arrivalDate')[-8:-3])
            info.append(flight.get('punctualityRate'))
            info.append(legs.get('characteristic').get('lowestPrice'))
            print(info)
            table.append(info)


if __name__ == "__main__":
    acity = '长沙'
    date = '20190915'
    for i in city.keys():
        print(i)
        try:
            if i != acity:
                xiecheng(i, acity, date)
        except Exception:
            print('没抓到')
            continue
    df=pd.DataFrame(table)
    df.to_excel('20190915长沙2.xls')
# Out:
# 黎平
# 没抓到
# 丽江
# 没抓到
# 荔波
# 没抓到
# 连云港
# 没抓到
# 六盘水
# 没抓到
# 临汾
# 没抓到
# 林芝
# 没抓到
# 临沧
# 没抓到
# 临沂
# 没抓到
# 柳州
# 没抓到
# 泸州
# 没抓到
# 洛阳
# 没抓到
# 吕梁
# 没抓到
# 澜沧
# 没抓到
# 龙岩
# 没抓到
# 满洲里
# 没抓到
# 梅州
# 没抓到
# 绵阳
# 没抓到
# 漠河
# 没抓到
# 牡丹江
# 没抓到
# 马祖
# 没抓到
# 南昌
# 没抓到
# 南充
# 没抓到
# 南京
# 没抓到
# 南宁
# 没抓到
# 南通
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-761e8f458a13> in <module>
#      72         try:
#      73             if i != acity:
# ---> 74                 xiecheng(i, acity, date)
#      75         except Exception:
#      76             print('没抓到')
#
# <ipython-input-10-761e8f458a13> in xiecheng(dcity, acity, date)
#      47
#      48     # 这里传进去的参数必须为 json 格式
# ---> 49     response = requests.post(url, data=json.dumps(request_payload), headers=headers).text
#      50     routeList = json.loads(response)["data"].get('routeList')
#      51     # print("123",routeList)
#
# /anaconda3/lib/python3.6/site-packages/requests/api.py in post(url, data, json, **kwargs)
#     114     """
#     115
# --> 116     return request('post', url, data=data, json=json, **kwargs)
#     117
#     118
#
# /anaconda3/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# /anaconda3/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /anaconda3/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     341         # Trigger any extra validation we need to do.
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#     345             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     837         # Force connect early to allow us to validate the connection.
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#     841         if not conn.is_verified:
#
# /anaconda3/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     299     def connect(self):
#     300         # Add certificate verification
# --> 301         conn = self._new_conn()
#     302         hostname = self.host
#     303
#
# /anaconda3/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     157         try:
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#     161         except SocketTimeout as e:
#
# /anaconda3/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      68             if source_address:
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#      72
#
# KeyboardInterrupt:
